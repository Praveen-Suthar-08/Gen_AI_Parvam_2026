# %%
from collections import Counter

def text_to_frequency(text):
    """
    Convert text to frequency count of words.
    Ignores order, just counts occurrences.
    """
    # Convert to lowercase and split into words
    words = text.lower().split()
    
    # Count word frequencies
    frequency = Counter(words)
    
    return frequency

# Example usage
sample_text = "hello world hello python world python python"
result = text_to_frequency(sample_text)
print(result)
# Out:
# Counter({'python': 3, 'hello': 2, 'world': 2})
