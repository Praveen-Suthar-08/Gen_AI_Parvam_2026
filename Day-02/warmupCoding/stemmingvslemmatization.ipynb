# %%
from nltk.stem import WordNetLemmatizer
import nltk

# Download required NLTK data (run once)
nltk.download('wordnet')
nltk.download('omw-1.4')

# Initialize the lemmatizer
lemmatizer = WordNetLemmatizer()


# Example words to lemmatize
words = ['running', 'runs', 'ran', 'easily', 'fairly', 'studies', 'studying']

# Lemmatize each word
lemmatized_words = [lemmatizer.lemmatize(word) for word in words]

print("Original words:", words)
print("Lemmatized words:", lemmatized_words)
# Out:
# [nltk_data] Downloading package wordnet to C:\Users\City
# [nltk_data]     College\AppData\Roaming\nltk_data...
# [nltk_data] Downloading package omw-1.4 to C:\Users\City
# [nltk_data]     College\AppData\Roaming\nltk_data...
# Original words: ['running', 'runs', 'ran', 'easily', 'fairly', 'studies', 'studying']
# Lemmatized words: ['running', 'run', 'ran', 'easily', 'fairly', 'study', 'studying']
